# %%
import sys
import time
import datetime
import logging
import DWM10_Parms
import DWM14_BuildRefDict
import DWM15_BuildLinkIndex
import DWM16_BuildTokenFreqDict
import DWM25_Global_Token_Replace
import DWM42_BuildBlockPairs
import DWM55_LinkBlockPairs
import DWM80_TransitiveClosure
import DWM90_IterateClusters
import DWM96_WriteLinkIndex
import DWM97_ClusterProfile
import DWM99_ERmetrics

# %%
# Main Driver for Refactored Data Washing Machine
# Version 1.20 creates a log file with same information being written to console
# Version 1.30 creates cluster profile at end of program and evaluates ER statistics
# Version 1.40 FK - added module DWM25 to do global level token replacement
#              JRT - added DWM65_ScoringMatrix to allow ScoringMatrix as a comparitor type
# Version 1.50 Revised and corrected scoring matrix
#              Revised DWM25 Global Replacement to reuse Tokenizer Dictionary and use DWM_WordList.txt
# Version 1.60 Implemented 2 versions of Scoring Rule - Standard (Std) and Weighted (Kris)
#              Changed Parms to be a class imported by all modules
# Version 1.70 Added new parameter minBlkTokenLen to set a minimum length for blokcing tokens
#              Improved performance of global cleaning
# Version 1.80 Added new parameter excludeNumericBlocks when True does not block on numeric tokens
#              Added new parameter removeExcludedBlkTokens when True removes tokens excluded by
#                 minBlkTokenLen & exludeNumbericBlocks
#              Added timer and added Total Runtime to logging statistics
# Version 1.90 Extensive refactor of the processing logic separating stop word removal from blocking.
#              Also generate and deduplicate pairs from all blocks before comparing or correcting references
#              Added a new parameter blockByPairs requiring refs in a block to share 2 tokens
#              Added MultiDriver for testing the 18 test files.
version = 1.90
# get start time for timer
startTime = time.time()
# date time is used to label the logfile
now = datetime.datetime.now()
tag = str(now.year)+(str(now.month)).zfill(2)+(str(now.day)).zfill(2)
tag = tag+'_'+(str(now.hour)).zfill(2)+'_'+(str(now.minute)).zfill(2)
logFile = open('DWM_Log_Multi_'+tag+'.txt','w')
print("Data Washing Machine Refactor Version",version)
print("Data Washing Machine Refactor Version",version, file=logFile)
print("Date/Time",tag)
print("Data/Time",tag, file=logFile)

fileName = "input.txt"
file1 = open(fileName, 'r')

while True:
    now1 = datetime.datetime.now()
    parmFileName = file1.readline()
    if not parmFileName or "#" in parmFileName:
        print('\nEnd of the parmFileName Runs')
        break
    print('\n\nRunning parms file',parmFileName)
    print('\nRunning parms file ',parmFileName, file=logFile)
    parmFileName = parmFileName.replace('\n','')
    DWM10_Parms.getParms(parmFileName, logFile)
    # Create refDict, a dictionary where key=refID, value is list of reference tokens
    refDict = DWM14_BuildRefDict.tokenizeInput()
    # Create linkIndx, a dictionary where key=refID, value is cluster ID
    linkIndex = DWM15_BuildLinkIndex.buildLinkIndex(refDict)
    # Create tokenFeqDict, a dictionary where key=token, value is token frequency
    tokenFreqDict =DWM16_BuildTokenFreqDict.buildTokenFreqDict(refDict)
    # create dictionary of corrections (stdTokenDict), leave empty if not running replacement
    #if global replacement configured, populate stdTokenDict of corrections in DWM25
    if DWM10_Parms.runGlobalCorrection:
        refDict = DWM25_Global_Token_Replace.globalReplace(refDict, tokenFreqDict)
        tokenFreqDict =DWM16_BuildTokenFreqDict.buildTokenFreqDict(refDict)
    moreToDo = True
    print('\n>>Starting Iterations')
    print('\n>>Starting Iterations', file=logFile)
    mu = DWM10_Parms.mu
    print('mu start value=', mu)
    print('mu start value=', mu, file=logFile)
    muIterate = DWM10_Parms.muIterate
    print('mu iterate value=', muIterate)
    print('mu iterate value=', muIterate, file=logFile)
    epsilon = DWM10_Parms.epsilon
    print('epsilon start value=', epsilon)
    print('epsilon start value=', epsilon, file=logFile)
    epsilonIterate = DWM10_Parms.epsilonIterate
    print('epsilon iterate value=', epsilonIterate)
    print('epsilon iterate value=', epsilonIterate, file=logFile)
    comparator = DWM10_Parms.comparator
    print('comparator =', comparator)
    print('comparator =', comparator, file=logFile)

    while moreToDo:
        print('\n****New Iteration\nSize of refDict =', len(refDict))   
        print('\n****New Iteration\nSize of refDict =', len(refDict), file=logFile)  
        #blockList = DWM40_BuildBlocks.buildBlocks(logFile, refList, tokenFreqDict)
        blockPairList = DWM42_BuildBlockPairs.buildBlockPairs(refDict, linkIndex, tokenFreqDict)
        if len(blockPairList)==0:
            print('--Ending because blockPairList is empty')
            print('--Ending because blockPairList is empty', file=logFile)
            break
        linkedPairList = DWM55_LinkBlockPairs.linkBlockPairs(blockPairList, refDict, tokenFreqDict)
        if len(linkedPairList)==0:
            print('Ending because linkedPairList is empty')
            print('Ending because linkedPairList is empty', file=logFile)
            break
        clusterList = DWM80_TransitiveClosure.transitiveClosure(linkedPairList)
        if len(clusterList)==0:
            print('--Ending because clusterList is empty') 
            print('--Ending because clusterList is empty', file=logFile)
            break  
        DWM90_IterateClusters.iterateClusters(clusterList, refDict, linkIndex)
        print('\n>>End of Iteration, Resetting mu and epsilon')
        print('\n>>End of Iteration, Resetting mu and epsilon', file=logFile)
        mu += muIterate
        mu = round(mu, 2)
        DWM10_Parms.mu = mu
        print('>>>New Value of mu = ',mu)
        print('>>>New Value of mu = ',mu, file=logFile)
        epsilon += epsilonIterate
        epsilon = round(epsilon, 2)
        DWM10_Parms.epsilon = epsilon
        print('>>>New Value of epsilon = ',epsilon)
        print('>>>New Value of epsilon = ',epsilon, file=logFile)
        if mu > 1.0:
            moreToDo = False
            print('Ending because mu > 1.0')
            print('Ending because mu > 1.0', file=logFile)
    # End of iterations
    # write Link Index to text file
    DWM96_WriteLinkIndex.writeLinkIndex(linkIndex)
    # Generate Cluster Profile
    DWM97_ClusterProfile.generateProfile(linkIndex)
    # Generat ER Metrics if truthFileName was given
    if DWM10_Parms.truthFileName != '':
        DWM99_ERmetrics.generateMetrics(linkIndex)
        #print('\nAbove ERMetrics for file',parmFileName)
    now2 = datetime.datetime.now()
    print("\nTotal File Runtime =", now2-now1, file=logFile)
    print("\nEnd of File ",parmFileName)
    print('Time to run File ', now2-now1)
    print("End of File ",parmFileName, file=logFile)   
file1.close()
endTime = time.time()
totalTime = endTime - startTime
print("All Files Total Runtime =", totalTime/60, " minutes")
print("\All Files Total Runtime =", totalTime/60, file=logFile)
print("End of Program")
print("End of Program", file=logFile)
logFile.close()
# Out:
# Data Washing Machine Refactor Version 1.9
# Date/Time 20210831_13_13
#
#
# Running parms file S5-parms.txt
#
#
# >> Starting DWM14
# Input Reference File Name = S5G.txt
# Input File has Header Records = True
# Input File Delimiter = ,
# Tokenizer Function Type = Splitter
# Remove Duplicate Reference Tokens = False
# Total References Read= 3004
# Total Tokens Found = 38106
#
# >>Starting DWM15
# LinkIndex created, record count = 3004
#
# >> Starting DWM16
# Total References Read= 3004
# Total Tokens Found = 38106
# Total Unique Tokens = 7190
# Minimum Token Frequency = 1
# Maximum Token Frequency = 2853
# Top Five Tokens by Freqency
#   Token= NC Frequency= 2853
#   Token= SALEM Frequency= 1881
#   Token= WINSTON Frequency= 1869
#   Token= DR Frequency= 813
#   Token= RD Frequency= 626
# Average Token Frequency = 5.299860917941586
# Standard Deviation of Token Frequency = 50.2307658022669
#
# >>Starting Iterations
# mu start value= 0.7
# mu iterate value= 0.05
# epsilon start value= 0.78
# epsilon iterate value= 0.0
# comparator = ScoringMatrixKris
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 3004
# Total Blocking Records Created 9006
# Total Blocks Size>1 Created 2814
# Total Pairs Generated by Blocks= 13489
# Total Unduplicated Pairs = 9126
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 1818 at mu= 0.7
# DWM_55-65 or 66 time to run  0:00:02.387961
# dW80 pairlist in length  1818
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.592254
# dW80 pairlist OUT length  1265
#
# >>Starting DWM90
# Total Clusters Processed = 777
# Total Clusters Size>1 Processed = 309
# Total Good Clusters = 683  at epsilon = 0.78
# Total References in Good Cluster = 978
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.75
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 2031
# Total Blocking Records Created 5493
# Total Blocks Size>1 Created 1487
# Total Pairs Generated by Blocks= 5092
# Total Unduplicated Pairs = 4049
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 329 at mu= 0.75
# DWM_55-65 or 66 time to run  0:00:01.121325
# dW80 pairlist in length  329
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.016995
# dW80 pairlist OUT length  229
#
# >>Starting DWM90
# Total Clusters Processed = 104
# Total Clusters Size>1 Processed = 75
# Total Good Clusters = 41  at epsilon = 0.78
# Total References in Good Cluster = 62
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.8
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1969
# Total Blocking Records Created 5278
# Total Blocks Size>1 Created 1436
# Total Pairs Generated by Blocks= 4485
# Total Unduplicated Pairs = 3678
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 182 at mu= 0.8
# DWM_55-65 or 66 time to run  0:00:01.018253
# dW80 pairlist in length  182
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.015624
# dW80 pairlist OUT length  123
#
# >>Starting DWM90
# Total Clusters Processed = 65
# Total Clusters Size>1 Processed = 39
# Total Good Clusters = 32  at epsilon = 0.78
# Total References in Good Cluster = 40
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.85
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1929
# Total Blocking Records Created 5143
# Total Blocks Size>1 Created 1414
# Total Pairs Generated by Blocks= 4112
# Total Unduplicated Pairs = 3467
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 89 at mu= 0.85
# DWM_55-65 or 66 time to run  0:00:00.977587
# dW80 pairlist in length  89
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  64
#
# >>Starting DWM90
# Total Clusters Processed = 33
# Total Clusters Size>1 Processed = 23
# Total Good Clusters = 14  at epsilon = 0.78
# Total References in Good Cluster = 21
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.9
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1908
# Total Blocking Records Created 5062
# Total Blocks Size>1 Created 1406
# Total Pairs Generated by Blocks= 3855
# Total Unduplicated Pairs = 3366
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 42 at mu= 0.9
# DWM_55-65 or 66 time to run  0:00:01.216772
# dW80 pairlist in length  42
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.001007
# dW80 pairlist OUT length  35
#
# >>Starting DWM90
# Total Clusters Processed = 20
# Total Clusters Size>1 Processed = 14
# Total Good Clusters = 7  at epsilon = 0.78
# Total References in Good Cluster = 8
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.95
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1900
# Total Blocking Records Created 5033
# Total Blocks Size>1 Created 1401
# Total Pairs Generated by Blocks= 3773
# Total Unduplicated Pairs = 3323
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 13 at mu= 0.95
# DWM_55-65 or 66 time to run  0:00:01.228366
# dW80 pairlist in length  13
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  10
#
# >>Starting DWM90
# Total Clusters Processed = 8
# Total Clusters Size>1 Processed = 2
# Total Good Clusters = 6  at epsilon = 0.78
# Total References in Good Cluster = 6
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.0
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 9
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1894
# Total Blocking Records Created 5015
# Total Blocks Size>1 Created 1396
# Total Pairs Generated by Blocks= 3734
# Total Unduplicated Pairs = 3303
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 38
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 5 at mu= 1.0
# DWM_55-65 or 66 time to run  0:00:01.202034
# dW80 pairlist in length  5
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  2
#
# >>Starting DWM90
# Total Clusters Processed = 1
# Total Clusters Size>1 Processed = 1
# Total Good Clusters = 0  at epsilon = 0.78
# Total References in Good Cluster = 0
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.05
# >>>New Value of epsilon =  0.78
# Ending because mu > 1.0
#
# >>Starting DWM96
# Record written to S5G-LinkIndex.txt = 3004
#
# >>Starting DWM97
#
# Cluster Profile
# Size	Count
# 1 	 1118 	 1118
# 2 	 543 	 1086
# 3 	 174 	 522
# 4 	 46 	 184
# 5 	 12 	 60
# 6 	 3 	 18
# 7 	 1 	 7
# 9 	 1 	 9
# 	Total	 3004
#
# >>Starting DWM99
# Truth File Name= truthABCgoodDQ.txt
# L= 1563.0 E= 1526.0 TP= 1371.0
# Precision= 0.8772
# Recall= 0.8984
# F-measure= 0.8877
#
# End of File  S5-parms.txt
# Time to run File  0:00:10.752581
#
#
# Running parms file S5-parms1.txt
#
#
# >> Starting DWM14
# Input Reference File Name = S5G.txt
# Input File has Header Records = True
# Input File Delimiter = ,
# Tokenizer Function Type = Splitter
# Remove Duplicate Reference Tokens = False
# Total References Read= 3004
# Total Tokens Found = 38106
#
# >>Starting DWM15
# LinkIndex created, record count = 3004
#
# >> Starting DWM16
# Total References Read= 3004
# Total Tokens Found = 38106
# Total Unique Tokens = 7190
# Minimum Token Frequency = 1
# Maximum Token Frequency = 2853
# Top Five Tokens by Freqency
#   Token= NC Frequency= 2853
#   Token= SALEM Frequency= 1881
#   Token= WINSTON Frequency= 1869
#   Token= DR Frequency= 813
#   Token= RD Frequency= 626
# Average Token Frequency = 5.299860917941586
# Standard Deviation of Token Frequency = 50.2307658022669
#
# >>Starting Iterations
# mu start value= 0.7
# mu iterate value= 0.05
# epsilon start value= 0.78
# epsilon iterate value= 0.0
# comparator = ScoringMatrixKris
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 3004
# Total Blocking Records Created 9526
# Total Blocks Size>1 Created 2864
# Total Pairs Generated by Blocks= 15939
# Total Unduplicated Pairs = 11137
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 2071 at mu= 0.7
# DWM_55-65 or 66 time to run  0:00:02.328992
# dW80 pairlist in length  2071
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.698704
# dW80 pairlist OUT length  1390
#
# >>Starting DWM90
# Total Clusters Processed = 768
# Total Clusters Size>1 Processed = 325
# Total Good Clusters = 637  at epsilon = 0.78
# Total References in Good Cluster = 913
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.75
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 2094
# Total Blocking Records Created 6053
# Total Blocks Size>1 Created 1600
# Total Pairs Generated by Blocks= 6818
# Total Unduplicated Pairs = 5383
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 573 at mu= 0.75
# DWM_55-65 or 66 time to run  0:00:01.158722
# dW80 pairlist in length  573
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.031223
# dW80 pairlist OUT length  361
#
# >>Starting DWM90
# Total Clusters Processed = 144
# Total Clusters Size>1 Processed = 107
# Total Good Clusters = 57  at epsilon = 0.78
# Total References in Good Cluster = 89
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.8
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 2005
# Total Blocking Records Created 5728
# Total Blocks Size>1 Created 1519
# Total Pairs Generated by Blocks= 5817
# Total Unduplicated Pairs = 4748
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 307 at mu= 0.8
# DWM_55-65 or 66 time to run  0:00:01.033600
# dW80 pairlist in length  307
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.015629
# dW80 pairlist OUT length  216
#
# >>Starting DWM90
# Total Clusters Processed = 102
# Total Clusters Size>1 Processed = 63
# Total Good Clusters = 53  at epsilon = 0.78
# Total References in Good Cluster = 71
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.85
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1934
# Total Blocking Records Created 5460
# Total Blocks Size>1 Created 1467
# Total Pairs Generated by Blocks= 4994
# Total Unduplicated Pairs = 4273
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 157 at mu= 0.85
# DWM_55-65 or 66 time to run  0:00:00.954205
# dW80 pairlist in length  157
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  114
#
# >>Starting DWM90
# Total Clusters Processed = 52
# Total Clusters Size>1 Processed = 35
# Total Good Clusters = 23  at epsilon = 0.78
# Total References in Good Cluster = 32
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.9
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1902
# Total Blocking Records Created 5352
# Total Blocks Size>1 Created 1447
# Total Pairs Generated by Blocks= 4683
# Total Unduplicated Pairs = 4099
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 80 at mu= 0.9
# DWM_55-65 or 66 time to run  0:00:00.923289
# dW80 pairlist in length  80
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  59
#
# >>Starting DWM90
# Total Clusters Processed = 32
# Total Clusters Size>1 Processed = 18
# Total Good Clusters = 16  at epsilon = 0.78
# Total References in Good Cluster = 19
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.95
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1883
# Total Blocking Records Created 5280
# Total Blocks Size>1 Created 1432
# Total Pairs Generated by Blocks= 4476
# Total Unduplicated Pairs = 3986
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 33 at mu= 0.95
# DWM_55-65 or 66 time to run  0:00:00.903179
# dW80 pairlist in length  33
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  21
#
# >>Starting DWM90
# Total Clusters Processed = 10
# Total Clusters Size>1 Processed = 5
# Total Good Clusters = 5  at epsilon = 0.78
# Total References in Good Cluster = 5
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.0
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1878
# Total Blocking Records Created 5267
# Total Blocks Size>1 Created 1430
# Total Pairs Generated by Blocks= 4444
# Total Unduplicated Pairs = 3968
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 26 at mu= 1.0
# DWM_55-65 or 66 time to run  0:00:00.870534
# dW80 pairlist in length  26
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  15
#
# >>Starting DWM90
# Total Clusters Processed = 5
# Total Clusters Size>1 Processed = 4
# Total Good Clusters = 1  at epsilon = 0.78
# Total References in Good Cluster = 1
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.05
# >>>New Value of epsilon =  0.78
# Ending because mu > 1.0
#
# >>Starting DWM96
# Record written to S5G-LinkIndex.txt = 3004
#
# >>Starting DWM97
#
# Cluster Profile
# Size	Count
# 1 	 1095 	 1095
# 2 	 543 	 1086
# 3 	 174 	 522
# 4 	 46 	 184
# 5 	 14 	 70
# 6 	 4 	 24
# 7 	 2 	 14
# 9 	 1 	 9
# 	Total	 3004
#
# >>Starting DWM99
# Truth File Name= truthABCgoodDQ.txt
# L= 1619.0 E= 1526.0 TP= 1354.0
# Precision= 0.8363
# Recall= 0.8873
# F-measure= 0.861
#
# End of File  S5-parms1.txt
# Time to run File  0:00:09.756495
#
#
# Running parms file S5-parms2.txt
#
#
# >> Starting DWM14
# Input Reference File Name = S5G.txt
# Input File has Header Records = True
# Input File Delimiter = ,
# Tokenizer Function Type = Splitter
# Remove Duplicate Reference Tokens = False
# Total References Read= 3004
# Total Tokens Found = 38106
#
# >>Starting DWM15
# LinkIndex created, record count = 3004
#
# >> Starting DWM16
# Total References Read= 3004
# Total Tokens Found = 38106
# Total Unique Tokens = 7190
# Minimum Token Frequency = 1
# Maximum Token Frequency = 2853
# Top Five Tokens by Freqency
#   Token= NC Frequency= 2853
#   Token= SALEM Frequency= 1881
#   Token= WINSTON Frequency= 1869
#   Token= DR Frequency= 813
#   Token= RD Frequency= 626
# Average Token Frequency = 5.299860917941586
# Standard Deviation of Token Frequency = 50.2307658022669
#
# >>Starting Iterations
# mu start value= 0.7
# mu iterate value= 0.05
# epsilon start value= 0.78
# epsilon iterate value= 0.0
# comparator = ScoringMatrixKris
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 3004
# Total Blocking Records Created 9526
# Total Blocks Size>1 Created 2864
# Total Pairs Generated by Blocks= 15939
# Total Unduplicated Pairs = 11137
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 2071 at mu= 0.7
# DWM_55-65 or 66 time to run  0:00:02.344432
# dW80 pairlist in length  2071
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.691845
# dW80 pairlist OUT length  1390
#
# >>Starting DWM90
# Total Clusters Processed = 768
# Total Clusters Size>1 Processed = 325
# Total Good Clusters = 637  at epsilon = 0.78
# Total References in Good Cluster = 913
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.75
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 2094
# Total Blocking Records Created 6053
# Total Blocks Size>1 Created 1600
# Total Pairs Generated by Blocks= 6818
# Total Unduplicated Pairs = 5383
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 573 at mu= 0.75
# DWM_55-65 or 66 time to run  0:00:01.170511
# dW80 pairlist in length  573
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.031252
# dW80 pairlist OUT length  361
#
# >>Starting DWM90
# Total Clusters Processed = 144
# Total Clusters Size>1 Processed = 107
# Total Good Clusters = 57  at epsilon = 0.78
# Total References in Good Cluster = 89
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.8
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 2005
# Total Blocking Records Created 5728
# Total Blocks Size>1 Created 1519
# Total Pairs Generated by Blocks= 5817
# Total Unduplicated Pairs = 4748
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 307 at mu= 0.8
# DWM_55-65 or 66 time to run  0:00:01.023388
# dW80 pairlist in length  307
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.015631
# dW80 pairlist OUT length  216
#
# >>Starting DWM90
# Total Clusters Processed = 102
# Total Clusters Size>1 Processed = 63
# Total Good Clusters = 53  at epsilon = 0.78
# Total References in Good Cluster = 71
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.85
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1934
# Total Blocking Records Created 5460
# Total Blocks Size>1 Created 1467
# Total Pairs Generated by Blocks= 4994
# Total Unduplicated Pairs = 4273
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 157 at mu= 0.85
# DWM_55-65 or 66 time to run  0:00:00.958716
# dW80 pairlist in length  157
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  114
#
# >>Starting DWM90
# Total Clusters Processed = 52
# Total Clusters Size>1 Processed = 35
# Total Good Clusters = 23  at epsilon = 0.78
# Total References in Good Cluster = 32
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.9
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1902
# Total Blocking Records Created 5352
# Total Blocks Size>1 Created 1447
# Total Pairs Generated by Blocks= 4683
# Total Unduplicated Pairs = 4099
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 80 at mu= 0.9
# DWM_55-65 or 66 time to run  0:00:00.925790
# dW80 pairlist in length  80
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00.015653
# dW80 pairlist OUT length  59
#
# >>Starting DWM90
# Total Clusters Processed = 32
# Total Clusters Size>1 Processed = 18
# Total Good Clusters = 16  at epsilon = 0.78
# Total References in Good Cluster = 19
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  0.95
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1883
# Total Blocking Records Created 5280
# Total Blocks Size>1 Created 1432
# Total Pairs Generated by Blocks= 4476
# Total Unduplicated Pairs = 3986
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 33 at mu= 0.95
# DWM_55-65 or 66 time to run  0:00:00.891713
# dW80 pairlist in length  33
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  21
#
# >>Starting DWM90
# Total Clusters Processed = 10
# Total Clusters Size>1 Processed = 5
# Total Good Clusters = 5  at epsilon = 0.78
# Total References in Good Cluster = 5
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.0
# >>>New Value of epsilon =  0.78
#
# ****New Iteration
# Size of refDict = 3004
#
# >>Starting DWM42
# beta = 11
# min blocking token length = 4
# exclude numeric blocking tokens = False
# block by pairs of tokens = False
# Total Records Selected for Reprocessing 1878
# Total Blocking Records Created 5267
# Total Blocks Size>1 Created 1430
# Total Pairs Generated by Blocks= 4444
# Total Unduplicated Pairs = 3968
# check Dictionary after DMW42
#
# >>Starting DWM55
# Sigma = 14
# Remove Duplicate Tokens = False
# Minimum Block Token Length = 4
# Exclude Numeric Blocks = False
# Remove Exluded Block Tokens = False
# Number of Pairs Linked = 26 at mu= 1.0
# DWM_55-65 or 66 time to run  0:00:00.914588
# dW80 pairlist in length  26
#
# >>Starting DWM80
# DWM_80 time to run  0:00:00
# dW80 pairlist OUT length  15
#
# >>Starting DWM90
# Total Clusters Processed = 5
# Total Clusters Size>1 Processed = 4
# Total Good Clusters = 1  at epsilon = 0.78
# Total References in Good Cluster = 1
#
# >>End of Iteration, Resetting mu and epsilon
# >>>New Value of mu =  1.05
# >>>New Value of epsilon =  0.78
# Ending because mu > 1.0
#
# >>Starting DWM96
# Record written to S5G-LinkIndex.txt = 3004
#
# >>Starting DWM97
#
# Cluster Profile
# Size	Count
# 1 	 1095 	 1095
# 2 	 543 	 1086
# 3 	 174 	 522
# 4 	 46 	 184
# 5 	 14 	 70
# 6 	 4 	 24
# 7 	 2 	 14
# 9 	 1 	 9
# 	Total	 3004
#
# >>Starting DWM99
# Truth File Name= truthABCgoodDQ.txt
# L= 1619.0 E= 1526.0 TP= 1354.0
# Precision= 0.8363
# Recall= 0.8873
# F-measure= 0.861
#
# End of File  S5-parms2.txt
# Time to run File  0:00:09.798955
#
# End of the parmFileName Runs
# All Files Total Runtime = 0.5052000641822815  minutes
# End of Program
